# %%
def get_string():
    print('Enter your input string:')
    phrase = input()
    character = 'abc'
    while len(character) >1:
        print('Enter the character you want to count its occurrences:')
        character = input()
        if len(character) >1:
            print('Type a valid input')

    return phrase.lower(),character.lower()

# %%
def count_occurrences(phrase,character):
    counter = 0
    for letter in phrase:
        if letter == character:
            counter +=1
    return counter   

def print_count(character,count_char):
    print('The count of the letter {} in the given sentence is {}'.format(character,count_char))

# %%
if __name__ == '__main__':
    phrase,character = get_string()
    count_char = count_occurrences(phrase,character)
    print_count(character,count_char)
# Out:
# Enter your input string:
#  The best thing about python is that there are plenty of sources and ways to apply your idea
# Enter the character you want to count its occurences:
#  e
# The count of the letter e in the given sentence is 8
